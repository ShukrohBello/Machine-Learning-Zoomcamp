# %%
pip install jupyter scikit-learn pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 55.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 52.0 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 36.7 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [jupyter-console]  WARNING: The script jupyter-console is installed in '/usr/local/python/3.12.1/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   Attempting uninstall: jupyterlab
#     Found existing installation: jupyterlab 4.4.4━━━━━━━━━━━━━ 3/7 [jupyter-console]
#     Uninstalling jupyterlab-4.4.4:m━━━━━━━━━━━━━━━━━━━━━━ 3/7 [jupyter-console]
#       Successfully uninstalled jupyterlab-4.4.40m━━━━━━━━━━━━━━━━━ 4/7 [jupyterlab]]
# ...

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/workshops/main/mlzoomcamp-fastapi-uv/starter.ipynb -O workshop-uv-fastapi.ipynb
# Out:
# --2025-11-06 11:04:47--  https://raw.githubusercontent.com/alexeygrigorev/workshops/main/mlzoomcamp-fastapi-uv/starter.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34627 (34K) [text/plain]
# Saving to: ‘workshop-uv-fastapi.ipynb’
#
# workshop-uv-fastapi 100%[===================>]  33.82K  --.-KB/s    in 0.002s
#
# 2025-11-06 11:04:48 (21.8 MB/s) - ‘workshop-uv-fastapi.ipynb’ saved [34627/34627]

# %%
pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 65.5 MB/s eta 0:00:00:00:01
# ...
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
uv init
# Out:
# Initialized project `05-deployment`
# Note: you may need to restart the kernel to use updated packages.

# %%
uv add scikit-learn==1.6.1 fastapi uvicorn
# Out:
# ⠙ Resolving dependencies...
# Resolved 21 packages in 1.39s
# Audited 19 packages in 228ms
# Note: you may need to restart the kernel to use updated packages.

# %%
# Define the data source and download location.
PREFIX = 'https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin'
POSTFIX = '../05-deployment'

# %%
# Get the model.
# !wget -O $POSTFIX/model1.bin $PREFIX/model1.bin
# Out:
# --2025-11-06 07:44:09--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin/model1.bin
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response...
# 404 Not Found
# 2025-11-06 07:44:10 ERROR 404: Not Found.

# %%
data = "wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin"

# %%
# !wget $data
# Out:
# --2025-11-06 08:00:12--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2025-11-06 08:00:12--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin [following]
# --2025-11-06 08:00:12--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# ...

# %%
uv add fastapi
# Out:
# Resolved 21 packages in 0.61ms
# Audited 19 packages in 0.15ms
# Note: you may need to restart the kernel to use updated packages.

# %%
uv pip install fastapi
# Out:
# Using Python 3.12.1 environment at: /usr/local/python/3.12.1
# Resolved 11 packages in 41ms
# ██████████░░░░░░░░░░ [6/11] pydantic-core==2.41.5
# Installed 11 packages in 267ms0
#  + annotated-doc==0.0.3
#  + annotated-types==0.7.0
#  + anyio==4.11.0
#  + fastapi==0.121.0
#  + idna==3.11
#  + pydantic==2.12.4
#  + pydantic-core==2.41.5
#  + sniffio==1.3.1
#  + starlette==0.49.3
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
# Note: you may need to restart the kernel to use updated packages.

# %%
uv run fast_api.py
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
uv pip install uvicorn
# Out:
# Using Python 3.12.1 environment at: /usr/local/python/3.12.1
# Resolved 3 packages in 20ms
# Installed 3 packages in 15ms
#  + click==8.3.0
#  + h11==0.16.0
#  + uvicorn==0.38.0
# Note: you may need to restart the kernel to use updated packages.
